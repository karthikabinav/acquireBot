# %% [markdown]
# # Bot Skeleton

# %% [markdown]
# The next cell will authenticate your bot based on your keys and tokens. See the [Tweepy tutorial](https://github.com/comp-journalism/UMD-J479V-J779V-Spring2016/blob/master/Weekly/Week_5/Tweepy-skeleton.ipynb) for more details.

# %%
import tweepy

#Setup and authenticate Tweepy
CONSUMER_KEY = "bauPKKi3FhjTI1852tliXN1wS"
CONSUMER_SECRET = "hdvix52Yip1pd4JpLdZbtGx2huMdw72Rl1HlGuCarOCdaPr3It"
ACCESS_TOKEN = "711314374925938688-hvusXUpXhBek0FOTpGF5ofmcdb22sJy"
ACCESS_TOKEN_SECRET = "pFAJfJoyeaBWoGC05mxntVxhqKLfLfUxprZVFSVvlHrey"

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

me = api.me()
print me.screen_name
# Out:
# acquirebot

# %% [markdown]
# The next cell has a number of essential functions that allow your bot to listen to the twitter stream and then respond. The assignment involves fleshing out the editorial logic of the bot and writing code in the sections marked "TODO".

# %%
import random
import json
import time
import feedparser #Library to read the parser
import pprint

# If debug_mode is True then the bot won't actually tweet. Set debug_mode = False for it to tweet. 
debug_mode = True

class AcquireBot():
    # Functions that allow the bot to tweet or reply to tweets
    def tweet(status):
        print "JUST TWEETED: ", status
        # Only *actually* send the tweet on twitter if we're not in debug mode
        if debug_mode == False:
            api.update_status(status)


    def obtain_feed():
        print "Obtaining the feed from techcrunch"
        techcrunch_startups_rss_url = "http://techcrunch.com/startups/feed/"
        feed = feedparser.parse(techcrunch_startups_rss_url)
        return feed

def main():
    feed = obtain_feed()
    pp = pprint.PrettyPrinter(indent=4)
    pp.pprint(feed)

# %%
main()
# Out:
# Obtaining the feed from techcrunch
# {   'bozo': 0,
#     'encoding': u'UTF-8',
#     'entries': [   {   'author': u'Larry Alton',
#                        'author_detail': {   'name': u'Larry Alton'},
#                        'authors': [{   'name': u'Larry Alton'}],
#                        'comments': u'http://techcrunch.com/2016/03/19/sesame-workshop-is-looking-for-startups-that-help-kids/#respond',
#                        'guidislink': False,
#                        'href': u'',
#                        'id': u'http://techcrunch.com/?p=1292155',
#                        'link': u'http://techcrunch.com/2016/03/19/sesame-workshop-is-looking-for-startups-that-help-kids/?ncid=rss',
#                        'links': [   {   'href': u'http://techcrunch.com/2016/03/19/sesame-workshop-is-looking-for-startups-that-help-kids/?ncid=rss',
#                                         'rel': u'alternate',
#                                         'type': u'text/html'}],
#                        'media_content': [   {   'medium': u'image',
#                                                 'type': u'image/jpeg',
#                                                 'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/92916724.jpg'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/92916724.jpg?w=150'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://1.gravatar.com/avatar/1e86d9c92b3cd6f22f7af2317d348375?s=96&d=identicon&r=G'}],
#                        'media_thumbnail': [   {   'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/92916724.jpg?w=210&h=158&crop=1'},
#                                               {   'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/92916724.jpg?w=150'}],
#                        'published': u'Sat, 19 Mar 2016 22:00:10 +0000',
#                        'published_parsed': time.struct_time(tm_year=2016, tm_mon=3, tm_mday=19, tm_hour=22, tm_min=0, tm_sec=10, tm_wday=5, tm_yday=79, tm_isdst=0),
#                        'slash_comments': u'0',
#                        'summary': u'<img alt="Big Bird (L) and other Sesame Street puppet characters pose next to temporary street sign November 9, 2009 at West 64th Street and Broadway in New York on the eve of the 40th anniversary of the broadcast of the children&#039;s television show. The sign is located across the street from Sesame Workshop&#039;s corporate headquarters which will launch the 40th season of Sesame Street on PBS on November 10. AFP PHOTO/Stan Honda" class="attachment-large size-large wp-post-image" height="452" src="https://tctechcrunch2011.files.wordpress.com/2016/03/92916724.jpg?w=680" width="680" />&nbsp;Sesame Workshop, the organization that brought to life the beloved &#8220;Sesame Street&#8221; and countless other programs, has announced a new venture arm to invest in apps that help children develop. Working jointly with venture capital firm Collaborative Fund (which has funded companies like Lyft and AltSchool), Sesame Workshop has formed a new organization called Collab+Sesame. <a href="http://techcrunch.com/2016/03/19/sesame-workshop-is-looking-for-startups-that-help-kids/?ncid=rss">Read More</a>',
#                        'summary_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                              'language': None,
#                                              'type': u'text/html',
#                                              'value': u'<img alt="Big Bird (L) and other Sesame Street puppet characters pose next to temporary street sign November 9, 2009 at West 64th Street and Broadway in New York on the eve of the 40th anniversary of the broadcast of the children&#039;s television show. The sign is located across the street from Sesame Workshop&#039;s corporate headquarters which will launch the 40th season of Sesame Street on PBS on November 10. AFP PHOTO/Stan Honda" class="attachment-large size-large wp-post-image" height="452" src="https://tctechcrunch2011.files.wordpress.com/2016/03/92916724.jpg?w=680" width="680" />&nbsp;Sesame Workshop, the organization that brought to life the beloved &#8220;Sesame Street&#8221; and countless other programs, has announced a new venture arm to invest in apps that help children develop. Working jointly with venture capital firm Collaborative Fund (which has funded companies like Lyft and AltSchool), Sesame Workshop has formed a new organization called Collab+Sesame. <a href="http://techcrunch.com/2016/03/19/sesame-workshop-is-looking-for-startups-that-help-kids/?ncid=rss">Read More</a>'},
#                        'tags': [   {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Column'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Startups'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'TC'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'sesame street'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'HBO'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'educational'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'kids apps'}],
#                        'title': u'Sesame Workshop is looking for startups that help kids',
#                        'title_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                            'language': None,
#                                            'type': u'text/plain',
#                                            'value': u'Sesame Workshop is looking for startups that help kids'},
#                        'twitter': u'LarryAlton3',
#                        'wfw_commentrss': u'http://techcrunch.com/2016/03/19/sesame-workshop-is-looking-for-startups-that-help-kids/feed/'},
#                    {   'author': u'Lance L. Smith',
#                        'author_detail': {   'name': u'Lance L. Smith'},
#                        'authors': [{   'name': u'Lance L. Smith'}],
#                        'comments': u'http://techcrunch.com/2016/03/19/why-unicorns-falter/#respond',
#                        'guidislink': False,
#                        'href': u'',
#                        'id': u'http://techcrunch.com/?p=1292147',
#                        'link': u'http://techcrunch.com/2016/03/19/why-unicorns-falter/?ncid=rss',
#                        'links': [   {   'href': u'http://techcrunch.com/2016/03/19/why-unicorns-falter/?ncid=rss',
#                                         'rel': u'alternate',
#                                         'type': u'text/html'}],
#                        'media_content': [   {   'medium': u'image',
#                                                 'type': u'image/png',
#                                                 'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/unicorn-jet.png'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/unicorn-jet.png?w=150'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://1.gravatar.com/avatar/1e86d9c92b3cd6f22f7af2317d348375?s=96&d=identicon&r=G'}],
#                        'media_thumbnail': [   {   'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/unicorn-jet.png?w=210&h=158&crop=1'},
#                                               {   'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/unicorn-jet.png?w=150'}],
#                        'published': u'Sat, 19 Mar 2016 19:00:47 +0000',
#                        'published_parsed': time.struct_time(tm_year=2016, tm_mon=3, tm_mday=19, tm_hour=19, tm_min=0, tm_sec=47, tm_wday=5, tm_yday=79, tm_isdst=0),
#                        'slash_comments': u'0',
#                        'summary': u'<img alt="unicorn-jet" class="attachment-large size-large wp-post-image" height="383" src="https://tctechcrunch2011.files.wordpress.com/2016/03/unicorn-jet.png?w=680" width="680" />&nbsp;In early February 2016, a study of financing deals reported by The Wall Street Journal found that investors are increasingly protecting themselves from IPOs that don&#8217;t perform as expected. This fallout is a continuation of the demise of the so-called &#8220;unicorn,&#8221; a tech startup with a pre-IPO valuation of over one billion dollars. <a href="http://techcrunch.com/2016/03/19/why-unicorns-falter/?ncid=rss">Read More</a>',
#                        'summary_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                              'language': None,
#                                              'type': u'text/html',
#                                              'value': u'<img alt="unicorn-jet" class="attachment-large size-large wp-post-image" height="383" src="https://tctechcrunch2011.files.wordpress.com/2016/03/unicorn-jet.png?w=680" width="680" />&nbsp;In early February 2016, a study of financing deals reported by The Wall Street Journal found that investors are increasingly protecting themselves from IPOs that don&#8217;t perform as expected. This fallout is a continuation of the demise of the so-called &#8220;unicorn,&#8221; a tech startup with a pre-IPO valuation of over one billion dollars. <a href="http://techcrunch.com/2016/03/19/why-unicorns-falter/?ncid=rss">Read More</a>'},
#                        'tags': [   {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Column'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Startups'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'TC'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Venture Capital'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'unicorns'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'venture capital'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'IPO'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'exit'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Amazon'}],
#                        'title': u'Why unicorns falter',
#                        'title_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                            'language': None,
#                                            'type': u'text/plain',
#                                            'value': u'Why unicorns falter'},
#                        'wfw_commentrss': u'http://techcrunch.com/2016/03/19/why-unicorns-falter/feed/'},
#                    {   'author': u'Ramphis Castro',
#                        'author_detail': {   'name': u'Ramphis Castro'},
#                        'authors': [{   'name': u'Ramphis Castro'}],
#                        'comments': u'http://techcrunch.com/2016/03/18/how-international-startups-are-supporting-new-york-city/#respond',
#                        'guidislink': False,
#                        'href': u'',
#                        'id': u'http://techcrunch.com/?p=1290200',
#                        'link': u'http://techcrunch.com/2016/03/18/how-international-startups-are-supporting-new-york-city/?ncid=rss',
#                        'links': [   {   'href': u'http://techcrunch.com/2016/03/18/how-international-startups-are-supporting-new-york-city/?ncid=rss',
#                                         'rel': u'alternate',
#                                         'type': u'text/html'}],
#                        'media_content': [   {   'medium': u'image',
#                                                 'type': u'image/jpeg',
#                                                 'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/shutterstock_156854057.jpg'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/shutterstock_156854057.jpg?w=150'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://1.gravatar.com/avatar/1e86d9c92b3cd6f22f7af2317d348375?s=96&d=identicon&r=G'}],
#                        'media_thumbnail': [   {   'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/shutterstock_156854057.jpg?w=210&h=158&crop=1'},
#                                               {   'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/shutterstock_156854057.jpg?w=150'}],
#                        'published': u'Sat, 19 Mar 2016 01:00:54 +0000',
#                        'published_parsed': time.struct_time(tm_year=2016, tm_mon=3, tm_mday=19, tm_hour=1, tm_min=0, tm_sec=54, tm_wday=5, tm_yday=79, tm_isdst=0),
#                        'slash_comments': u'0',
#                        'summary': u'<img alt="New York City skyline" class="attachment-large size-large wp-post-image" height="453" src="https://tctechcrunch2011.files.wordpress.com/2016/03/shutterstock_156854057.jpg?w=680" width="680" />&nbsp;Immigrants make up 13.3 percent of the population in the U.S., which is the highest percentage the country has seen in more than 100 years. Now let&#8217;s put this into perspective: Thirty-six percent of all top tech founders in the U.S. are immigrants &#8212; almost triple the percentage of immigrants in the country. Many immigrants are pushing innovation in the U.S, aiding the country&#8230; <a href="http://techcrunch.com/2016/03/18/how-international-startups-are-supporting-new-york-city/?ncid=rss">Read More</a>',
#                        'summary_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                              'language': None,
#                                              'type': u'text/html',
#                                              'value': u'<img alt="New York City skyline" class="attachment-large size-large wp-post-image" height="453" src="https://tctechcrunch2011.files.wordpress.com/2016/03/shutterstock_156854057.jpg?w=680" width="680" />&nbsp;Immigrants make up 13.3 percent of the population in the U.S., which is the highest percentage the country has seen in more than 100 years. Now let&#8217;s put this into perspective: Thirty-six percent of all top tech founders in the U.S. are immigrants &#8212; almost triple the percentage of immigrants in the country. Many immigrants are pushing innovation in the U.S, aiding the country&#8230; <a href="http://techcrunch.com/2016/03/18/how-international-startups-are-supporting-new-york-city/?ncid=rss">Read More</a>'},
#                        'tags': [   {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Column'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Startups'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'TC'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'new york city'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'diversity in technology'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'immigration'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'immigration reform'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'H-1B visa'}],
#                        'title': u'How international startups are supporting New York City',
#                        'title_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                            'language': None,
#                                            'type': u'text/plain',
#                                            'value': u'How international startups are supporting New York City'},
#                        'twitter': u'jramphis',
#                        'wfw_commentrss': u'http://techcrunch.com/2016/03/18/how-international-startups-are-supporting-new-york-city/feed/'},
#                    {   'author': u'Josh Constine',
#                        'author_detail': {   'name': u'Josh Constine'},
#                        'authors': [{   'name': u'Josh Constine'}],
#                        'comments': u'http://techcrunch.com/2016/03/18/meter-feeder/#respond',
#                        'guidislink': False,
#                        'href': u'',
#                        'id': u'http://techcrunch.com/?p=1293832',
#                        'link': u'http://techcrunch.com/2016/03/18/meter-feeder/?ncid=rss',
#                        'links': [   {   'href': u'http://techcrunch.com/2016/03/18/meter-feeder/?ncid=rss',
#                                         'rel': u'alternate',
#                                         'type': u'text/html'}],
#                        'media_content': [   {   'medium': u'image',
#                                                 'type': u'image/jpeg',
#                                                 'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/no-more-parking-meters.jpg'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/no-more-parking-meters.jpg?w=150'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://0.gravatar.com/avatar/fd3b857e7f0024396cdbd36c4c102a5d?s=96&d=identicon&r=G'},
#                                             {   'medium': u'image',
#                                                 'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/meter-feeder1.png?w=680'},
#                                             {   'medium': u'image',
#                                                 'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/12841401_1859973967562866_6833192665254777874_o.jpg?w=378'},
#                                             {   'medium': u'image',
#                                                 'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/906351_1703124236581174_6449446172435413728_o.png?w=680'}],
#                        'media_thumbnail': [   {   'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/no-more-parking-meters.jpg?w=210&h=158&crop=1'},
#                                               {   'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/no-more-parking-meters.jpg?w=150'}],
#                        'published': u'Fri, 18 Mar 2016 20:52:38 +0000',
#                        'published_parsed': time.struct_time(tm_year=2016, tm_mon=3, tm_mday=18, tm_hour=20, tm_min=52, tm_sec=38, tm_wday=4, tm_yday=78, tm_isdst=0),
#                        'slash_comments': u'0',
#                        'summary': u'<img alt="No More Parking Meters" class="attachment-large size-large wp-post-image" height="383" src="https://tctechcrunch2011.files.wordpress.com/2016/03/no-more-parking-meters.jpg?w=680" width="680" />&nbsp;Parking tickets actually earn cities less money than when people pay the meters like they should. The problem is that even new meters that let you pay by phone or credit are such a hassle that people don&#8217;t use them &#8212; and hope they don&#8217;t get caught. But Y Combinator startup Meter Feeder has built a way to pay for parking that is\xa0easier for citizens, cheaper for cities and&hellip; <a href="http://techcrunch.com/2016/03/18/meter-feeder/?ncid=rss">Read More</a>',
#                        'summary_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                              'language': None,
#                                              'type': u'text/html',
#                                              'value': u'<img alt="No More Parking Meters" class="attachment-large size-large wp-post-image" height="383" src="https://tctechcrunch2011.files.wordpress.com/2016/03/no-more-parking-meters.jpg?w=680" width="680" />&nbsp;Parking tickets actually earn cities less money than when people pay the meters like they should. The problem is that even new meters that let you pay by phone or credit are such a hassle that people don&#8217;t use them &#8212; and hope they don&#8217;t get caught. But Y Combinator startup Meter Feeder has built a way to pay for parking that is\xa0easier for citizens, cheaper for cities and&hellip; <a href="http://techcrunch.com/2016/03/18/meter-feeder/?ncid=rss">Read More</a>'},
#                        'tags': [   {   'label': None,
#                                        'scheme': None,
#                                        'term': u'eCommerce'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Government'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Mobile'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Startups'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'TC'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Meter Feeder'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'parking'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Parking Tickets'}],
#                        'title': u'Meter Feeder lets you ditch coins and codes, pay for parking with GPS',
#                        'title_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                            'language': None,
#                                            'type': u'text/plain',
#                                            'value': u'Meter Feeder lets you ditch coins and codes, pay for parking with GPS'},
#                        'wfw_commentrss': u'http://techcrunch.com/2016/03/18/meter-feeder/feed/'},
#                    {   'author': u'Anthony Ha',
#                        'author_detail': {   'name': u'Anthony Ha'},
#                        'authors': [{   'name': u'Anthony Ha'}],
#                        'comments': u'http://techcrunch.com/2016/03/18/coach-launch/#respond',
#                        'guidislink': False,
#                        'href': u'',
#                        'id': u'http://techcrunch.com/?p=1291380',
#                        'link': u'http://techcrunch.com/2016/03/18/coach-launch/?ncid=rss',
#                        'links': [   {   'href': u'http://techcrunch.com/2016/03/18/coach-launch/?ncid=rss',
#                                         'rel': u'alternate',
#                                         'type': u'text/html'}],
#                        'media_content': [   {   'medium': u'image',
#                                                 'type': u'image/jpeg',
#                                                 'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/shutterstock_195367244.jpg'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/shutterstock_195367244.jpg?w=150'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://1.gravatar.com/avatar/72b358648f4587cc2a11895c32b8e979?s=96&d=identicon&r=G'},
#                                             {   'medium': u'image',
#                                                 'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/calendar.jpg?w=680'}],
#                        'media_thumbnail': [   {   'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/shutterstock_195367244.jpg?w=210&h=158&crop=1'},
#                                               {   'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/shutterstock_195367244.jpg?w=150'}],
#                        'published': u'Fri, 18 Mar 2016 19:33:43 +0000',
#                        'published_parsed': time.struct_time(tm_year=2016, tm_mon=3, tm_mday=18, tm_hour=19, tm_min=33, tm_sec=43, tm_wday=4, tm_yday=78, tm_isdst=0),
#                        'slash_comments': u'0',
#                        'summary': u'<img alt="empty classroom with computers" class="attachment-large size-large wp-post-image" height="408" src="https://tctechcrunch2011.files.wordpress.com/2016/03/shutterstock_195367244.jpg?w=680" width="680" />&nbsp;If you&#8217;re a tutor looking to offer your services online, a startup called Coach aims to give you the tools you need. CEO Spencer Fry created a similar platform, in some ways, when he co-founded\xa0CarbonMade, which offers designers and artists an easy way to showcase their portfolios online. He said there&#8217;s a bigger challenge with Coach, though, because there are more pieces to&hellip; <a href="http://techcrunch.com/2016/03/18/coach-launch/?ncid=rss">Read More</a>',
#                        'summary_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                              'language': None,
#                                              'type': u'text/html',
#                                              'value': u'<img alt="empty classroom with computers" class="attachment-large size-large wp-post-image" height="408" src="https://tctechcrunch2011.files.wordpress.com/2016/03/shutterstock_195367244.jpg?w=680" width="680" />&nbsp;If you&#8217;re a tutor looking to offer your services online, a startup called Coach aims to give you the tools you need. CEO Spencer Fry created a similar platform, in some ways, when he co-founded\xa0CarbonMade, which offers designers and artists an easy way to showcase their portfolios online. He said there&#8217;s a bigger challenge with Coach, though, because there are more pieces to&hellip; <a href="http://techcrunch.com/2016/03/18/coach-launch/?ncid=rss">Read More</a>'},
#                        'tags': [   {   'label': None,
#                                        'scheme': None,
#                                        'term': u'eCommerce'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Startups'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'TC'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'coach'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'notation capital'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'spencer-fry'}],
#                        'title': u'Coach gives tutors and other freelancers tools to build an online business',
#                        'title_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                            'language': None,
#                                            'type': u'text/plain',
#                                            'value': u'Coach gives tutors and other freelancers tools to build an online business'},
#                        'wfw_commentrss': u'http://techcrunch.com/2016/03/18/coach-launch/feed/'},
#                    {   'author': u'Jay Donovan',
#                        'author_detail': {   'name': u'Jay Donovan'},
#                        'authors': [{   'name': u'Jay Donovan'}],
#                        'comments': u'http://techcrunch.com/2016/03/18/yc-backed-perlstein-lab-continues-their-rare-disease-drug-discovery/#respond',
#                        'guidislink': False,
#                        'href': u'',
#                        'id': u'http://techcrunch.com/?p=1293401',
#                        'link': u'http://techcrunch.com/2016/03/18/yc-backed-perlstein-lab-continues-their-rare-disease-drug-discovery/?ncid=rss',
#                        'links': [   {   'href': u'http://techcrunch.com/2016/03/18/yc-backed-perlstein-lab-continues-their-rare-disease-drug-discovery/?ncid=rss',
#                                         'rel': u'alternate',
#                                         'type': u'text/html'}],
#                        'media_content': [   {   'medium': u'image',
#                                                 'type': u'image/jpeg',
#                                                 'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/plab.jpg'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/plab.jpg?w=150'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://0.gravatar.com/avatar/6daa3435dba08780d9e786be094ba75b?s=96&d=identicon&r=G'}],
#                        'media_thumbnail': [   {   'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/plab.jpg?w=210&h=158&crop=1'},
#                                               {   'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/plab.jpg?w=150'}],
#                        'published': u'Fri, 18 Mar 2016 16:58:51 +0000',
#                        'published_parsed': time.struct_time(tm_year=2016, tm_mon=3, tm_mday=18, tm_hour=16, tm_min=58, tm_sec=51, tm_wday=4, tm_yday=78, tm_isdst=0),
#                        'slash_comments': u'0',
#                        'summary': u'<img alt="plab" class="attachment-large size-large wp-post-image" height="270" src="https://tctechcrunch2011.files.wordpress.com/2016/03/plab.jpg?w=680" width="680" />&nbsp;Perlstein Lab, or PLab as it is also known, continues to hone its automated drug discovery platform and presents its latest iteration Wednesday March 23rd at Y Combinator Demo Day. The platform they created helps the bio startup focus on finding cures for rare diseases rather than common ones. This novel approach is different from most Big Pharma labs and is thus one of their differentiators. <a href="http://techcrunch.com/2016/03/18/yc-backed-perlstein-lab-continues-their-rare-disease-drug-discovery/?ncid=rss">Read More</a>',
#                        'summary_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                              'language': None,
#                                              'type': u'text/html',
#                                              'value': u'<img alt="plab" class="attachment-large size-large wp-post-image" height="270" src="https://tctechcrunch2011.files.wordpress.com/2016/03/plab.jpg?w=680" width="680" />&nbsp;Perlstein Lab, or PLab as it is also known, continues to hone its automated drug discovery platform and presents its latest iteration Wednesday March 23rd at Y Combinator Demo Day. The platform they created helps the bio startup focus on finding cures for rare diseases rather than common ones. This novel approach is different from most Big Pharma labs and is thus one of their differentiators. <a href="http://techcrunch.com/2016/03/18/yc-backed-perlstein-lab-continues-their-rare-disease-drug-discovery/?ncid=rss">Read More</a>'},
#                        'tags': [   {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Bio'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Health'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Startups'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'TC'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Perlstein Lab'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'PLab'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'biomedical'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'biotech'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Ethan Perlstein'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Pharmaceutical'}],
#                        'title': u'YC-backed Perlstein Lab continues their rare disease drug discovery',
#                        'title_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                            'language': None,
#                                            'type': u'text/plain',
#                                            'value': u'YC-backed Perlstein Lab continues their rare disease drug discovery'},
#                        'wfw_commentrss': u'http://techcrunch.com/2016/03/18/yc-backed-perlstein-lab-continues-their-rare-disease-drug-discovery/feed/'},
#                    {   'author': u'Ingrid Lunden',
#                        'author_detail': {   'name': u'Ingrid Lunden'},
#                        'authors': [{   'name': u'Ingrid Lunden'}],
#                        'comments': u'http://techcrunch.com/2016/03/18/stripes-startup-toolkit-atlas-opens-for-business-in-cuba/#respond',
#                        'guidislink': False,
#                        'href': u'',
#                        'id': u'http://techcrunch.com/?p=1293485',
#                        'link': u'http://techcrunch.com/2016/03/18/stripes-startup-toolkit-atlas-opens-for-business-in-cuba/?ncid=rss',
#                        'links': [   {   'href': u'http://techcrunch.com/2016/03/18/stripes-startup-toolkit-atlas-opens-for-business-in-cuba/?ncid=rss',
#                                         'rel': u'alternate',
#                                         'type': u'text/html'}],
#                        'media_content': [   {   'medium': u'image',
#                                                 'type': u'image/jpeg',
#                                                 'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/13343022465_0dea0bc26b_k.jpg'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/13343022465_0dea0bc26b_k.jpg?w=150'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://0.gravatar.com/avatar/6648ec93043f0f368091adece63c6d52?s=96&d=identicon&r=G'}],
#                        'media_thumbnail': [   {   'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/13343022465_0dea0bc26b_k.jpg?w=210&h=158&crop=1'},
#                                               {   'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/13343022465_0dea0bc26b_k.jpg?w=150'}],
#                        'published': u'Fri, 18 Mar 2016 16:00:22 +0000',
#                        'published_parsed': time.struct_time(tm_year=2016, tm_mon=3, tm_mday=18, tm_hour=16, tm_min=0, tm_sec=22, tm_wday=4, tm_yday=78, tm_isdst=0),
#                        'slash_comments': u'0',
#                        'summary': u'<img alt="cuba" class="attachment-large size-large wp-post-image" height="504" src="https://tctechcrunch2011.files.wordpress.com/2016/03/13343022465_0dea0bc26b_k.jpg?w=680" width="680" />&nbsp;A month ago, payments company Stripe launched Atlas,\xa0a toolkit for startups\xa0to incorporate in the U.S. and lay the groundwork for growing\xa0their businesses online. Aimed largely at small\xa0enterprises\xa0outside of the U.S., Atlas is\xa0making a notable\xa0addition to the\xa0roster of countries covered under the program: from today, it will begin to accept Atlas applicants from\xa0Cuba, so that&hellip; <a href="http://techcrunch.com/2016/03/18/stripes-startup-toolkit-atlas-opens-for-business-in-cuba/?ncid=rss">Read More</a>',
#                        'summary_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                              'language': None,
#                                              'type': u'text/html',
#                                              'value': u'<img alt="cuba" class="attachment-large size-large wp-post-image" height="504" src="https://tctechcrunch2011.files.wordpress.com/2016/03/13343022465_0dea0bc26b_k.jpg?w=680" width="680" />&nbsp;A month ago, payments company Stripe launched Atlas,\xa0a toolkit for startups\xa0to incorporate in the U.S. and lay the groundwork for growing\xa0their businesses online. Aimed largely at small\xa0enterprises\xa0outside of the U.S., Atlas is\xa0making a notable\xa0addition to the\xa0roster of countries covered under the program: from today, it will begin to accept Atlas applicants from\xa0Cuba, so that&hellip; <a href="http://techcrunch.com/2016/03/18/stripes-startup-toolkit-atlas-opens-for-business-in-cuba/?ncid=rss">Read More</a>'},
#                        'tags': [   {   'label': None,
#                                        'scheme': None,
#                                        'term': u'eCommerce'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Enterprise'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Startups'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'TC'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'stripe'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'payments'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'cuba'}],
#                        'title': u'Stripe\u2019s startup toolkit Atlas opens for business in Cuba',
#                        'title_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                            'language': None,
#                                            'type': u'text/plain',
#                                            'value': u'Stripe\u2019s startup toolkit Atlas opens for business in Cuba'},
#                        'wfw_commentrss': u'http://techcrunch.com/2016/03/18/stripes-startup-toolkit-atlas-opens-for-business-in-cuba/feed/'},
#                    {   'author': u'Jordan Crook',
#                        'author_detail': {   'name': u'Jordan Crook'},
#                        'authors': [{   'name': u'Jordan Crook'}],
#                        'comments': u'http://techcrunch.com/2016/03/18/managed-by-q-gives-five-percent-of-the-company-equity-to-office-operators/#respond',
#                        'guidislink': False,
#                        'href': u'',
#                        'id': u'http://techcrunch.com/?p=1293624',
#                        'link': u'http://techcrunch.com/2016/03/18/managed-by-q-gives-five-percent-of-the-company-equity-to-office-operators/?ncid=rss',
#                        'links': [   {   'href': u'http://techcrunch.com/2016/03/18/managed-by-q-gives-five-percent-of-the-company-equity-to-office-operators/?ncid=rss',
#                                         'rel': u'alternate',
#                                         'type': u'text/html'}],
#                        'media_content': [   {   'medium': u'image',
#                                                 'type': u'image/jpeg',
#                                                 'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/q-28.jpg'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/q-28.jpg?w=150'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://1.gravatar.com/avatar/123a4c264172746af556b0c74c72b308?s=96&d=identicon&r=G'}],
#                        'media_thumbnail': [   {   'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/q-28.jpg?w=210&h=158&crop=1'},
#                                               {   'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/q-28.jpg?w=150'}],
#                        'published': u'Fri, 18 Mar 2016 15:40:08 +0000',
#                        'published_parsed': time.struct_time(tm_year=2016, tm_mon=3, tm_mday=18, tm_hour=15, tm_min=40, tm_sec=8, tm_wday=4, tm_yday=78, tm_isdst=0),
#                        'slash_comments': u'0',
#                        'summary': u'<img alt="Q-28" class="attachment-large size-large wp-post-image" height="454" src="https://tctechcrunch2011.files.wordpress.com/2016/03/q-28.jpg?w=680" width="680" />&nbsp;Managed By Q, the company that lets you order on-demand cleaning services, IT help, handyman work and more all from an iPad in the office, has today announced a new stock option plan for its office and field Operators.\nThe program, which will give back 5 percent of the company to Operators, applies to all employees of the company, regardless of role, starting on July 1, and the program will&#8230; <a href="http://techcrunch.com/2016/03/18/managed-by-q-gives-five-percent-of-the-company-equity-to-office-operators/?ncid=rss">Read More</a>',
#                        'summary_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                              'language': None,
#                                              'type': u'text/html',
#                                              'value': u'<img alt="Q-28" class="attachment-large size-large wp-post-image" height="454" src="https://tctechcrunch2011.files.wordpress.com/2016/03/q-28.jpg?w=680" width="680" />&nbsp;Managed By Q, the company that lets you order on-demand cleaning services, IT help, handyman work and more all from an iPad in the office, has today announced a new stock option plan for its office and field Operators.\nThe program, which will give back 5 percent of the company to Operators, applies to all employees of the company, regardless of role, starting on July 1, and the program will&#8230; <a href="http://techcrunch.com/2016/03/18/managed-by-q-gives-five-percent-of-the-company-equity-to-office-operators/?ncid=rss">Read More</a>'},
#                        'tags': [   {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Collaborative Consumption'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Policy'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Startups'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'TC'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'managed by q'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Handy'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Uber'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Shyp'}],
#                        'title': u'Managed By Q gives five percent of the company equity to its Operators',
#                        'title_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                            'language': None,
#                                            'type': u'text/plain',
#                                            'value': u'Managed By Q gives five percent of the company equity to its Operators'},
#                        'wfw_commentrss': u'http://techcrunch.com/2016/03/18/managed-by-q-gives-five-percent-of-the-company-equity-to-office-operators/feed/'},
#                    {   'author': u'Nik Milanovic',
#                        'author_detail': {   'name': u'Nik Milanovic'},
#                        'authors': [{   'name': u'Nik Milanovic'}],
# ...
#                        'title_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                            'language': None,
#                                            'type': u'text/plain',
#                                            'value': u'GoButler pivots to fully-automated service, starting with flight search and discovery'},
#                        'wfw_commentrss': u'http://techcrunch.com/2016/03/17/a-pivot-please/feed/'},
#                    {   'author': u'Steve O&#039;Hear',
#                        'author_detail': {   'name': u'Steve O&#039;Hear'},
#                        'authors': [{   'name': u'Steve O&#039;Hear'}],
#                        'comments': u'http://techcrunch.com/2016/03/17/distribusion-the-startup-that-makes-it-easy-to-sell-intercity-bus-tickets-picks-up-e6-million-funding/#respond',
#                        'guidislink': False,
#                        'href': u'',
#                        'id': u'http://techcrunch.com/?p=1293134',
#                        'link': u'http://techcrunch.com/2016/03/17/distribusion-the-startup-that-makes-it-easy-to-sell-intercity-bus-tickets-picks-up-e6-million-funding/?ncid=rss',
#                        'links': [   {   'href': u'http://techcrunch.com/2016/03/17/distribusion-the-startup-that-makes-it-easy-to-sell-intercity-bus-tickets-picks-up-e6-million-funding/?ncid=rss',
#                                         'rel': u'alternate',
#                                         'type': u'text/html'}],
#                        'media_content': [   {   'medium': u'image',
#                                                 'type': u'image/png',
#                                                 'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/screen-shot-2016-03-17-at-13-01-48.png'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/screen-shot-2016-03-17-at-13-01-48.png?w=150'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://0.gravatar.com/avatar/95b8a6df6d265cf57a4d89ee4856ea98?s=96&d=identicon&r=G'}],
#                        'media_thumbnail': [   {   'url': u'https://tctechcrunch2011.files.wordpress.com/2016/03/screen-shot-2016-03-17-at-13-01-48.png?w=210&h=158&crop=1'},
#                                               {   'url': u'http://tctechcrunch2011.files.wordpress.com/2016/03/screen-shot-2016-03-17-at-13-01-48.png?w=150'}],
#                        'published': u'Thu, 17 Mar 2016 14:00:18 +0000',
#                        'published_parsed': time.struct_time(tm_year=2016, tm_mon=3, tm_mday=17, tm_hour=14, tm_min=0, tm_sec=18, tm_wday=3, tm_yday=77, tm_isdst=0),
#                        'slash_comments': u'0',
#                        'summary': u'<img alt="Distribusion" class="attachment-large size-large wp-post-image" height="308" src="https://tctechcrunch2011.files.wordpress.com/2016/03/screen-shot-2016-03-17-at-13-01-48.png?w=680" width="680" />&nbsp;Distribusion, the Berlin-based startup that&#8217;s built a platform to make it easy for travel companies and travel search engines to sell &#8216;intercity&#8217; bus tickets, has picked up \u20ac6 million in funding. Backing comes from Northzone, Creandum, and HR Ventures. Existing seed investor Fr\xfchphasenfonds Brandenburg, along with a number of travel industry-related angels, also participated. <a href="http://techcrunch.com/2016/03/17/distribusion-the-startup-that-makes-it-easy-to-sell-intercity-bus-tickets-picks-up-e6-million-funding/?ncid=rss">Read More</a>',
#                        'summary_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                              'language': None,
#                                              'type': u'text/html',
#                                              'value': u'<img alt="Distribusion" class="attachment-large size-large wp-post-image" height="308" src="https://tctechcrunch2011.files.wordpress.com/2016/03/screen-shot-2016-03-17-at-13-01-48.png?w=680" width="680" />&nbsp;Distribusion, the Berlin-based startup that&#8217;s built a platform to make it easy for travel companies and travel search engines to sell &#8216;intercity&#8217; bus tickets, has picked up \u20ac6 million in funding. Backing comes from Northzone, Creandum, and HR Ventures. Existing seed investor Fr\xfchphasenfonds Brandenburg, along with a number of travel industry-related angels, also participated. <a href="http://techcrunch.com/2016/03/17/distribusion-the-startup-that-makes-it-easy-to-sell-intercity-bus-tickets-picks-up-e6-million-funding/?ncid=rss">Read More</a>'},
#                        'tags': [   {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Europe'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Fundings & Exits'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Startups'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'TC'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Distribusion'}],
#                        'title': u'Distribusion, the startup that makes it easy to sell intercity bus tickets, picks up \u20ac6 million funding',
#                        'title_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                            'language': None,
#                                            'type': u'text/plain',
#                                            'value': u'Distribusion, the startup that makes it easy to sell intercity bus tickets, picks up \u20ac6 million funding'},
#                        'wfw_commentrss': u'http://techcrunch.com/2016/03/17/distribusion-the-startup-that-makes-it-easy-to-sell-intercity-bus-tickets-picks-up-e6-million-funding/feed/'},
#                    {   'author': u'Matt Burns',
#                        'author_detail': {   'name': u'Matt Burns'},
#                        'authors': [{   'name': u'Matt Burns'}],
#                        'comments': u'http://techcrunch.com/2016/03/17/want-to-display-in-startup-alley-at-disrupt-ny-for-free-enter-our-giveaway/#respond',
#                        'guidislink': False,
#                        'href': u'',
#                        'id': u'http://techcrunch.com/?p=1289195',
#                        'link': u'http://techcrunch.com/2016/03/17/want-to-display-in-startup-alley-at-disrupt-ny-for-free-enter-our-giveaway/?ncid=rss',
#                        'links': [   {   'href': u'http://techcrunch.com/2016/03/17/want-to-display-in-startup-alley-at-disrupt-ny-for-free-enter-our-giveaway/?ncid=rss',
#                                         'rel': u'alternate',
#                                         'type': u'text/html'}],
#                        'media_content': [   {   'medium': u'image',
#                                                 'type': u'image/jpeg',
#                                                 'url': u'https://tctechcrunch2011.files.wordpress.com/2014/05/startup-alley15.jpg'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://tctechcrunch2011.files.wordpress.com/2014/05/startup-alley15.jpg?w=150'},
#                                             {   'medium': u'image',
#                                                 'url': u'http://0.gravatar.com/avatar/c921fdee122025b0436360dc6bb7322d?s=96&d=identicon&r=G'}],
#                        'media_thumbnail': [   {   'url': u'https://tctechcrunch2011.files.wordpress.com/2014/05/startup-alley15.jpg?w=210&h=158&crop=1'},
#                                               {   'url': u'http://tctechcrunch2011.files.wordpress.com/2014/05/startup-alley15.jpg?w=150'}],
#                        'published': u'Thu, 17 Mar 2016 13:00:20 +0000',
#                        'published_parsed': time.struct_time(tm_year=2016, tm_mon=3, tm_mday=17, tm_hour=13, tm_min=0, tm_sec=20, tm_wday=3, tm_yday=77, tm_isdst=0),
#                        'slash_comments': u'0',
#                        'summary': u'<img alt="startup-alley15" class="attachment-large size-large wp-post-image" height="453" src="https://tctechcrunch2011.files.wordpress.com/2014/05/startup-alley15.jpg?w=680" width="680" />&nbsp;Is your startup looking to take that next big leap forward? Many companies have gotten their start by displaying in Startup Alley at TechCrunch Disrupt, and we want your company to be our next success story. <a href="http://techcrunch.com/2016/03/17/want-to-display-in-startup-alley-at-disrupt-ny-for-free-enter-our-giveaway/?ncid=rss">Read More</a>',
#                        'summary_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                              'language': None,
#                                              'type': u'text/html',
#                                              'value': u'<img alt="startup-alley15" class="attachment-large size-large wp-post-image" height="453" src="https://tctechcrunch2011.files.wordpress.com/2014/05/startup-alley15.jpg?w=680" width="680" />&nbsp;Is your startup looking to take that next big leap forward? Many companies have gotten their start by displaying in Startup Alley at TechCrunch Disrupt, and we want your company to be our next success story. <a href="http://techcrunch.com/2016/03/17/want-to-display-in-startup-alley-at-disrupt-ny-for-free-enter-our-giveaway/?ncid=rss">Read More</a>'},
#                        'tags': [   {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Startups'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'TC'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Startup Alley'},
#                                    {   'label': None,
#                                        'scheme': None,
#                                        'term': u'Disrupt NY 2016'}],
#                        'title': u'Want to display in Startup Alley at Disrupt NY for free? Enter our giveaway',
#                        'title_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                            'language': None,
#                                            'type': u'text/plain',
#                                            'value': u'Want to display in Startup Alley at Disrupt NY for free? Enter our giveaway'},
#                        'wfw_commentrss': u'http://techcrunch.com/2016/03/17/want-to-display-in-startup-alley-at-disrupt-ny-for-free-enter-our-giveaway/feed/'}],
#     'etag': u'"d0f611889dd9ab3b3a34048108d9db00"',
#     'feed': {   'cloud': {   'domain': u'techcrunch.com',
#                              'path': u'/?rsscloud=notify',
#                              'port': u'80',
#                              'protocol': u'http-post',
#                              'registerprocedure': u''},
#                 'generator': u'http://wordpress.com/',
#                 'generator_detail': {   'name': u'http://wordpress.com/'},
#                 'image': {   'href': u'http://1.gravatar.com/blavatar/d9ea925a71f82f06a1e6224298f7fe80?s=96&d=http%3A%2F%2Fs2.wp.com%2Fi%2Fbuttonw-com.png',
#                              'link': u'http://techcrunch.com',
#                              'links': [   {   'href': u'http://techcrunch.com',
#                                               'rel': u'alternate',
#                                               'type': u'text/html'}],
#                              'title': u'Startups \u2013 TechCrunch',
#                              'title_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                                  'language': None,
#                                                  'type': u'text/plain',
#                                                  'value': u'Startups \u2013 TechCrunch'}},
#                 'language': u'en',
#                 'link': u'http://techcrunch.com',
#                 'links': [   {   'href': u'http://techcrunch.com/startups/feed/',
#                                  'rel': u'self',
#                                  'type': u'application/rss+xml'},
#                              {   'href': u'http://techcrunch.com',
#                                  'rel': u'alternate',
#                                  'type': u'text/html'},
#                              {   'href': u'http://techcrunch.com/osd.xml',
#                                  'rel': u'search',
#                                  'title': u'TechCrunch',
#                                  'type': u'application/opensearchdescription+xml'},
#                              {   'href': u'http://techcrunch.com/?pushpress=hub',
#                                  'rel': u'hub',
#                                  'type': u'text/html'}],
#                 'subtitle': u'Startup and Technology News',
#                 'subtitle_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                        'language': None,
#                                        'type': u'text/html',
#                                        'value': u'Startup and Technology News'},
#                 'sy_updatefrequency': u'1',
#                 'sy_updateperiod': u'hourly',
#                 'title': u'Startups \u2013 TechCrunch',
#                 'title_detail': {   'base': u'http://techcrunch.com/startups/feed/',
#                                     'language': None,
#                                     'type': u'text/plain',
#                                     'value': u'Startups \u2013 TechCrunch'},
#                 'updated': u'Sat, 19 Mar 2016 22:34:10 +0000',
#                 'updated_parsed': time.struct_time(tm_year=2016, tm_mon=3, tm_mday=19, tm_hour=22, tm_min=34, tm_sec=10, tm_wday=5, tm_yday=79, tm_isdst=0)},
#     'headers': {   'connection': 'close',
#                    'content-type': 'application/rss+xml; charset=UTF-8',
#                    'date': 'Sat, 19 Mar 2016 22:38:42 GMT',
#                    'etag': '"d0f611889dd9ab3b3a34048108d9db00"',
#                    'last-modified': 'Sat, 19 Mar 2016 22:34:10 GMT',
#                    'server': 'nginx',
#                    'transfer-encoding': 'chunked',
#                    'vary': 'Cookie',
#                    'x-ac': '4.dca _dca',
#                    'x-hacker': "If you're reading this, you should visit automattic.com/jobs and apply to join the fun, mention this header.",
#                    'x-nananana': 'Batcache'},
#     'href': u'http://techcrunch.com/startups/feed/',
#     'namespaces': {   '': u'http://www.w3.org/2005/Atom',
#                       'content': u'http://purl.org/rss/1.0/modules/content/',
#                       'dc': u'http://purl.org/dc/elements/1.1/',
#                       'geo': u'http://www.w3.org/2003/01/geo/wgs84_pos#',
#                       'georss': u'http://www.georss.org/georss',
#                       'media': u'http://search.yahoo.com/mrss/',
#                       'slash': u'http://purl.org/rss/1.0/modules/slash/',
#                       'sy': u'http://purl.org/rss/1.0/modules/syndication/',
#                       'wfw': u'http://wellformedweb.org/CommentAPI/'},
#     'status': 200,
#     'updated': 'Sat, 19 Mar 2016 22:34:10 GMT',
#     'updated_parsed': time.struct_time(tm_year=2016, tm_mon=3, tm_mday=19, tm_hour=22, tm_min=34, tm_sec=10, tm_wday=5, tm_yday=79, tm_isdst=0),
#     'version': u'rss20'}
